# %%
import marvin
from marvin import config
config.access = 'public'

import warnings
warnings.filterwarnings('ignore')

# %%
from whan import WHAN

# %%
# WHAN diagram for MaNGA galaxy with plateifu = 9511-12704
WHAN('9511-12704').diagram_plot()
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\MAMENCITA\AppData\Local\Programs\Python\Python38\lib\site-packages\marvin\tools\mixins\mma.py", line 132, in __init__
#     self._doLocal()
#   File "C:\Users\MAMENCITA\AppData\Local\Programs\Python\Python38\lib\site-packages\marvin\tools\mixins\mma.py", line 291, in _doLocal
#     raise MarvinError('failed to retrieve data using '
# marvin.core.exceptions.MarvinError: failed to retrieve data using input parameters.
# You can submit this error to Marvin GitHub Issues (https://github.com/sdss/marvin/issues/new).
# Fill out a subject and some text describing the error that just occurred.
# If able, copy and paste the full traceback information into the issue as well.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\MAMENCITA\AppData\Local\Programs\Python\Python38\lib\logging\handlers.py", line 70, in emit
#     self.doRollover()
# ...

# %%
# WHAN map for MaNGA galaxy with plateifu = 9511-12704
WHAN('9511-12704').map_plot()
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\MAMENCITA\AppData\Local\Programs\Python\Python38\lib\site-packages\marvin\tools\mixins\mma.py", line 132, in __init__
#     self._doLocal()
#   File "C:\Users\MAMENCITA\AppData\Local\Programs\Python\Python38\lib\site-packages\marvin\tools\mixins\mma.py", line 291, in _doLocal
#     raise MarvinError('failed to retrieve data using '
# marvin.core.exceptions.MarvinError: failed to retrieve data using input parameters.
# You can submit this error to Marvin GitHub Issues (https://github.com/sdss/marvin/issues/new).
# Fill out a subject and some text describing the error that just occurred.
# If able, copy and paste the full traceback information into the issue as well.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\MAMENCITA\AppData\Local\Programs\Python\Python38\lib\logging\handlers.py", line 70, in emit
#     self.doRollover()
# ...
